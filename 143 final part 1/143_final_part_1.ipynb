# %%
from csv_to_dataframe_time_amount import *
from number_of_tweet_over_time import *
from number_of_mention_per_person import *

# %%
# directory = 'C:\\Users\\drill\\OneDrive\\Desktop\\143 final\\tweet_2017_to_2019_with_hashtags.csv'
directory = 'tweet_2017_to_2019_with_hashtags.csv'
df = csv_to_dataframe_time_amount(directory)

# %%
number_of_tweet_over_time(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6ff32bc9-a688-4c3f-b65c-534919f54a98" data-root-id="1002"></div>
# Figure(id='1002', ...)

# %%
number_of_mention_per_person(directory)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1121">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9dd9dc2c-61ab-4b43-8ce9-6ed1d7b9b0f4" data-root-id="1122"></div>
# Figure(id='1122', ...)
